# %%
from get_tweet import get_tweet
from Analysis import Analysis
# Out:
# TwitterAPIで取得したAPI consumer key/secret　・　Access Token/Secretを入力します
# API consumer key(CK)を入力してください
# API consumer secret(CS)を入力してください
# Access Token(AT)を入力してください
# Access Secret(AS)を入力してください

# %%
get_tweet()

# %%
Analysis()
# Out:
# 分析結果を格納するフォルダ名を入力してください。resultフォルダの中に新しく作成されます 旅行最終
# 分析するtwitterデータファイルをdataフォルダに入れて、そのファイル名を入力してください(.csvまで) 旅行20-08-15-10-58.csv
# 分析可能なデータは362件です
# 各ツイートがポジティブなのかネガティブなのか判定しています。時間がかかるためしばらくお待ちください
# 判定が完了しました
#   0%|          | 0/24 [00:00<?, ?it/s]
# 分析するキーワードについてポジティブにツイートしたユーザーを、プロフィール情報に基づいてクラスタリングします
# 以下に表示されるグラフは何クラスタに分けるかの目安です。横軸がクラスタ数です。グラフ出力後に入力を求められます
# 水色のCoherenceが高い値かつ、グレーのPerplexityが低い値を示す数値がうまく分けられるクラスタ数だとされています
# しかし正確なものでは無いため、分析する目的や結果を見て調整してください。
# ...
#   0%|          | 0/24 [00:00<?, ?it/s]
# 分析するキーワードについてネガティブにツイートしたユーザーを、プロフィール情報に基づいてクラスタ分けします
# 以下に表示されるグラフは何クラスタに分けるかの目安です。横軸がクラスタ数です。グラフ出力後に入力を求められます
# 水色のCoherenceが高い値かつ、グレーのPerplexityが低い値を示す数値がうまく分けられるクラスタ数だとされています
# しかし正確なものでは無いため、分析する目的や結果を見て調整してください。
# 100%|██████████| 24/24 [00:33<00:00,  1.38s/it]
# ポジティブクラスタはいくつに分けますか？数字を半角で入力してください 4
# ネガティブクラスタはいくつに分けますか？数字を半角で入力してください 2
# クラスタリングした結果がresultフォルダのpositive/negative_groupフォルダに保存されます
# グループ数を変更して分析し直す場合は[1]を、終了する場合は[2]を押してください 2
